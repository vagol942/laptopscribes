# %%
import pandas as pd

# %%
data = pd.read_excel('laptops.xlsx')

# %%
data
# Out:
#      amazon_id                      name     brand  rating  price  \
# 0   B075FLBJV7          Acer Aspire E 15      Acer     4.0    599
# 1   B0762S8PYM      ASUS VivoBook F510UA      Asus     4.0    509
# 2   B078BC1YL2    Acer Swift 3 - Ryzen 3      Acer     4.0    749
# 3   B07H9RVTM8    Acer Swift 3 - Ryzen 5      Acer     4.0    949
# 4   B07CTHLX8C      Acer Predator Helios      Acer     4.0   1199
# 5   B06WVMJ713        Lenovo Legion Y720    Lenovo     4.0    814
# 6   B07C9J1PY6                   Dell G3      Dell     4.0    769
# 7   B07FLPG56B                   Dell G7      Dell     4.0   1349
# 8   B07D37VBVD               Razer Blade     Razer     4.5   2989
# 9   B07BB7XN8C     MSI GS65 Stealth Thin       MSI     4.5   1899
# 10  B07BNZ6Z9M     MSI GS65 Stealth Thin       MSI     4.5   2499
# 11  B07BSXCCHK         GYGABITE Aero 15X  Gygabite     4.5   2299
# 12  B07BSKLV3K             Asus Zephyrus      Asus     4.0   2199
# ...
